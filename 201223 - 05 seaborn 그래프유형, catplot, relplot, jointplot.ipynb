# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import font_manager, rc
import platform
# 그래프를 노트북 안에 그리기 위해 설정
# %matplotlib inline
#style must be one of white, dark, whitegrid, darkgrid, ticks
sns.set(style='darkgrid') #그래프 백그라운드 컬러, 얘가 폰트설정보다 위에있어야함
if platform.system() == 'Windows':
    # 유저가 다운받은 폰트는 밑의 경로에 있다.
    font_name = font_manager.FontProperties\
    (fname="C:\\Users\\RealSongBook\\AppData\\Local\\Microsoft\\Windows\\Fonts\\D2Coding-Ver1.3.2-20180524.ttc")\
    .get_name() # <=== 이런 경로가  내PC에선 안먹힘 "C:/Windows/Fonts/malgun.ttf"
    rc('font', family=font_name) # <== 왜인지 모르지만 안먹힘
    plt.rc('font', family=font_name) # <=== 그래프의 한글폰트지정
else:    
# Mac 인 경우
    rc('font', family='AppleGothic')

matplotlib.rcParams['axes.unicode_minus'] = False
import warnings
warnings.filterwarnings('ignore')
# plt.rc('font', family=font_name) # <=== 그래프의 한글폰트지정

# %%
temp = [0,0,3,7,5,3,0,1]

y = np.array(temp)
x = [ str(i)+'일' for i in range(1, len(y)+1)]

plt.bar(x,y)
plt.show()

# %%
tips = sns.load_dataset('tips')

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.head(3)
# 비용, 팁, 성별, 흡연여부, 요일, 시간, 인원수
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
# 그림 스타일 relation 중심 replot, 분류중심 catplot, jointplot
sns.relplot(x='total_bill', y='tip', data=tips, hue='sex', row='smoker', col='day')

# %%
sns.relplot(x='total_bill', y='tip', data=tips, style='smoker', hue='size')

# %%
sns.relplot(x='total_bill', y='tip', data=tips, hue='time',\
            palette=['b','r'], size='size',col='time')

# %%
whos
# Out:
# Variable       Type         Data/Info
# -------------------------------------
# font_manager   module       <module 'matplotlib.font_<...>lotlib\\font_manager.py'>
# font_name      str          D2Coding
# matplotlib     module       <module 'matplotlib' from<...>matplotlib\\__init__.py'>
# np             module       <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# pd             module       <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# platform       module       <module 'platform' from '<...>onda3\\lib\\platform.py'>
# plt            module       <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>
# rc             function     <function rc at 0x000002B410993A60>
# sns            module       <module 'seaborn' from 'C<...>s\\seaborn\\__init__.py'>
# temp           list         n=8
# tips           DataFrame         total_bill   tip    <...>n\n[244 rows x 7 columns]
# warnings       module       <module 'warnings' from '<...>onda3\\lib\\warnings.py'>
# ...

# %%
sns.__version__
# Out:
# '0.10.1'

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind='swarm') # swarm - 기어오르다.

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind='box')

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind='violin')

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind='violin', split=True, hue='sex')

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind='swarm', hue='sex')

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(x='sex', y='survived', data=titanic, hue='class', kind='bar')

# %%
df = pd.DataFrame(np.random.randn(500,2), columns=['0','1']) # 정규분포 데이터를 생성한다. randn()

# %%
df
# Out:
#             0         1
# 0   -0.759947  1.068708
# 1   -0.715655  0.030936
# 2   -1.202677  0.457166
# 3   -1.117788  0.631205
# 4   -0.186043  0.667657
# ..        ...       ...
# 495  1.257601  0.198326
# 496 -1.022807 -0.524439
# 497 -0.486538  0.212590
# 498 -1.486010 -2.353155
# 499  0.680324  0.530909
#
# [500 rows x 2 columns]

# %%
sns.relplot(x='0',y='1', data=df )

# %%
sns.jointplot(x='0',y='1', data=df )

# %%
sns.jointplot(x='0',y='1', data=df, kind='reg')
